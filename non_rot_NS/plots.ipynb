# %%
import numpy as np
import pylab as plt

rc = {"font.family" : "serif", 
      "mathtext.fontset" : "cm",
      "font.size" : "12",
      "figure.figsize" : [8,8]}
plt.rcParams.update(rc)

# %config InlineBackend.figure_format='retina'

# %%
data = np.genfromtxt("outseq.d")

# %%
plt.plot(data[:,0], data[:,2])
plt.xlabel(r'$R[R_\odot]$')
plt.ylabel(r'$M[M_\odot]$')
plt.title('mass-radius')
plt.show()

# %%
plt.plot(data[:,6], data[:,2])
plt.xlabel(r'$\log{h_c}$')
plt.ylabel(r'$M[M_\odot]$')
plt.title('mass-enthalpy')
plt.show()
